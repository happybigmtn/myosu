# %%
import sympy as sp
import numpy as np
from sympy import symbols,Eq,solve,Rational,integrate

# %%
x = symbols('x')
expr = (1-2/(1+x**2))
solve(expr,x)
# Out:
# [-1, 1]

# %%
x = symbols('x',real=True)
expr = x**2-1 
integrate(sp.Abs(expr),(x,0,2)).doit()
# Out:
# Integral(Piecewise((x**2 - 1, x**2 >= 1), (1 - x**2, True)), (x, 0, 2))
